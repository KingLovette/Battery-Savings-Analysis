# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
data = {
    'Hour': [...],
    'Date/hour start': [...],
    'Solar electricity generation (kWh)': [...],
    'Electricity usage (kWh)': [...]
}

# Load data into a DataFrame
df = pd.DataFrame(data)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Hour']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 21
#      18     raise ValueError("Data lengths do not match")
#      20 # Calculate the average values for each hour of the day
# ---> 21 df['Hour'] = pd.to_datetime(df['Hour']).dt.hour
#      22 average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()
#      24 # Create a graph to visualize the average values
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:833, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:655, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: <class 'ellipsis'> is not convertible to datetime

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst_Data.xlsx'
df = pd.read_excel(file_path)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 # Load data from Excel file
#       6 file_path = '/Users/admin/Downloads/Junior Data Analyst_Data.xlsx'
# ----> 7 df = pd.read_excel(file_path)
#       9 # Check if the data lengths match
#      10 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/excel/_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/excel/_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/admin/Downloads/Junior Data Analyst_Data.xlsx'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst_Data.xlsx'
df = pd.read_excel(file_path)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 # Load data from Excel file
#       6 file_path = '/Users/admin/Downloads/Junior Data Analyst_Data.xlsx'
# ----> 7 df = pd.read_excel(file_path)
#       9 # Check if the data lengths match
#      10 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/excel/_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/excel/_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/excel/_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/admin/Downloads/Junior Data Analyst_Data.xlsx'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path)

# %%
# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar electricity generation (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Check if the data lengths match
# ----> 2 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#       3     raise ValueError("Data lengths do not match")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Solar electricity generation (kWh)'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")

# Calculate the average values for each hour of the day
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar electricity generation (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 10
#       7 df = pd.read_excel(file_path)
#       9 # Check if the data lengths match
# ---> 10 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#      11     raise ValueError("Data lengths do not match")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Solar electricity generation (kWh)'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar electricity generation (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 10
#       7 df = pd.read_excel(file_path)
#       9 # Check if the data lengths match
# ---> 10 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#      11     raise ValueError("Data lengths do not match")
#      13 # Calculate the average values for each hour of the day
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Solar electricity generation (kWh)'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar electricity generation (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 10
#       7 df = pd.read_excel(file_path)
#       9 # Check if the data lengths match
# ---> 10 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#      11     raise ValueError("Data lengths do not match")
#      13 # Calculate the average values for each hour of the day
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Solar electricity generation (kWh)'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path)

# Check if the data lengths match
if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
    raise ValueError("Data lengths do not match")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Solar electricity generation (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 10
#       7 df = pd.read_excel(file_path)
#       9 # Check if the data lengths match
# ---> 10 if len(df['Solar electricity generation (kWh)']) != len(df['Electricity usage (kWh)']):
#      11     raise ValueError("Data lengths do not match")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Solar electricity generation (kWh)'

# %%
import pandas as pd

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path)

# Print the column names
print(df.columns)
# Out:
# Index([' Hour 0 represents the hour from midnight to 01:00 and hour 23 represents the hour from 23:00 to midnight.',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file, specifying header starts from the second row
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=1)

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date/hour start'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 10
#       7 df = pd.read_excel(file_path, header=1)
#       9 # Calculate the average values for each hour of the day
# ---> 10 df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
#      11 average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()
#      13 # Create a graph to visualize the average values
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Date/hour start'

# %%
import pandas as pd

# Load data from Excel file, specifying header starts from the second row
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=1)

# Print the column names to check
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'DATA', 'DATA.1'], dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file, specifying header starts from the second row
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=1)

# Rename columns to appropriate names
df.rename(columns={'Unnamed: 0': 'Hour', 'Unnamed: 1': 'Date/hour start', 'DATA': 'Solar electricity generation (kWh)', 'DATA.1': 'Electricity usage (kWh)'}, inplace=True)

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/anaconda3/lib/python3.10/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: Date/hour start
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "Date/hour start" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 13
#      10 df.rename(columns={'Unnamed: 0': 'Hour', 'Unnamed: 1': 'Date/hour start', 'DATA': 'Solar electricity generation (kWh)', 'DATA.1': 'Electricity usage (kWh)'}, inplace=True)
#      12 # Calculate the average values for each hour of the day
# ---> 13 df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
#      14 average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()
#      16 # Create a graph to visualize the average values
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/anaconda3/lib/python3.10/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: Date/hour start present at position 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data from Excel file, specifying header starts from the third row
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)

# Rename columns to appropriate names
df.rename(columns={'Unnamed: 0': 'Hour', 'Unnamed: 1': 'Date/hour start', 'DATA': 'Solar electricity generation (kWh)', 'DATA.1': 'Electricity usage (kWh)'}, inplace=True)

# Calculate the average values for each hour of the day
df['Hour'] = pd.to_datetime(df['Date/hour start']).dt.hour
average_values = df.groupby('Hour')[['Solar electricity generation (kWh)', 'Electricity usage (kWh)']].mean()

# Create a graph to visualize the average values
plt.figure(figsize=(10, 6))
plt.plot(average_values.index, average_values['Solar electricity generation (kWh)'], label='Average Solar Generation')
plt.plot(average_values.index, average_values['Electricity usage (kWh)'], label='Average Electricity Usage')
plt.xlabel('Hour of the Day')
plt.ylabel('kWh')
plt.title('Average Solar Generation and Electricity Usage by Hour')
plt.xticks(range(24))
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate the extra electricity from solar and battery combination for each hour
df['Extra Electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']
df['Extra Electricity (kWh)'] = np.maximum(df['Extra Electricity (kWh)'] - 12.5, 0)  # Subtract battery capacity if necessary

# Create a graph to visualize the extra electricity
plt.figure(figsize=(10, 6))
plt.plot(df['Hour'], df['Extra Electricity (kWh)'])
plt.xlabel('Hour of the Day')
plt.ylabel('Extra Electricity (kWh)')
plt.title('Extra Electricity from Solar and Battery Combination')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %%
# Calculate the dollar savings from installing the battery
electricity_price = 0.17  # $/kWh
df['Dollar Savings ($)'] = df['Extra Electricity (kWh)'] * electricity_price

# Total dollar savings over the entire period
total_dollar_savings = df['Dollar Savings ($)'].sum()
print("Total Dollar Savings from Installing the Battery:", total_dollar_savings)
# Out:
# Total Dollar Savings from Installing the Battery: 0.0618853720000004

# %%
# Calculate the shortfall for each hour
df['Shortfall (kWh)'] = df['Electricity usage (kWh)'] - df['Solar electricity generation (kWh)']

# Calculate the amount of electricity needed to be bought (subject to minimum of zero)
df['Electricity Bought (kWh)'] = np.maximum(df['Shortfall (kWh)'], 0)

# Create a graph to visualize the amount of electricity bought
plt.figure(figsize=(10, 6))
plt.bar(df['Hour'], df['Electricity Bought (kWh)'])
plt.xlabel('Hour of the Day')
plt.ylabel('Electricity Bought (kWh)')
plt.title('Amount of Electricity Bought from Electricity Provider')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %%
# Calculate the excess solar electricity for each hour
df['Excess Solar Electricity (kWh)'] = np.maximum(df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)'], 0)

# Create a graph to visualize the excess solar electricity
plt.figure(figsize=(10, 6))
plt.bar(df['Hour'], df['Excess Solar Electricity (kWh)'])
plt.xlabel('Hour of the Day')
plt.ylabel('Excess Solar Electricity (kWh)')
plt.title('Excess Solar Electricity Generated over Electricity Used')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %%
# Initialize cumulative battery charge level and cap
cumulative_charge = 0
battery_capacity = 12.5

# Calculate cumulative battery charge level for each hour
cumulative_charge_levels = []
for index, row in df.iterrows():
    excess_solar = row['Excess Solar Electricity (kWh)']
    electricity_bought = row['Electricity Bought (kWh)']
    
    # Calculate net charge (excess solar minus electricity bought)
    net_charge = excess_solar - electricity_bought
    
    # Update cumulative battery charge level
    cumulative_charge = cumulative_charge + net_charge
    cumulative_charge = min(cumulative_charge, battery_capacity)  # Apply cap
    
    cumulative_charge_levels.append(cumulative_charge)

# Add the cumulative battery charge levels to the DataFrame
df['Cumulative Battery Charge (kWh)'] = cumulative_charge_levels

# Create a graph to visualize the cumulative battery charge level
plt.figure(figsize=(10, 6))
plt.plot(df['Hour'], df['Cumulative Battery Charge (kWh)'])
plt.xlabel('Hour of the Day')
plt.ylabel('Cumulative Battery Charge (kWh)')
plt.title('Cumulative Battery Charge Level Over 2020')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %%
# Initialize variables
cumulative_charge = 0
battery_capacity = 12.5
electricity_bought_with_battery = []

# Calculate electricity bought with battery for each hour
for index, row in df.iterrows():
    excess_solar = row['Excess Solar Electricity (kWh)']
    electricity_bought = row['Electricity Bought (kWh)']
    
    # Calculate net charge (excess solar minus electricity bought)
    net_charge = excess_solar - electricity_bought
    
    # Calculate electricity bought from electricity provider with battery
    if net_charge < 0:  # Electricity needed
        electricity_bought_with_battery.append(-net_charge)
    else:
        electricity_bought_with_battery.append(0)
    
    # Update cumulative battery charge level
    cumulative_charge = cumulative_charge + net_charge
    cumulative_charge = min(cumulative_charge, battery_capacity)  # Apply cap

# Add the calculated electricity bought with battery to the DataFrame
df['Electricity Bought with Battery (kWh)'] = electricity_bought_with_battery

# Create a graph to visualize the amount of electricity bought with battery
plt.figure(figsize=(10, 6))
plt.bar(df['Hour'], df['Electricity Bought with Battery (kWh)'])
plt.xlabel('Hour of the Day')
plt.ylabel('Electricity Bought with Battery (kWh)')
plt.title('Amount of Electricity Bought from Electricity Provider with Battery')
plt.xticks(range(24))
plt.grid(True)
plt.show()

# %%
# Given data
electricity_price_2022 = 0.17  # $/kWh

# Calculate cost of electricity bought without battery
cost_without_battery = df['Electricity Bought (kWh)'].sum() * electricity_price_2022

# Calculate cost of electricity bought with battery
cost_with_battery = df['Electricity Bought with Battery (kWh)'].sum() * electricity_price_2022

# Calculate savings from installing a battery
savings = cost_without_battery - cost_with_battery

print(f"Savings over 2020 from installing a battery: ${savings:.2f}")
# Out:
# Savings over 2020 from installing a battery: $0.00

# %%
# Electricity prices
initial_electricity_price = 0.17
annual_inflation_rate = 0.04
additional_inflation_rate = 0.0025

# Calculate electricity cost for each hour using existing solar panels alone
df['Electricity Cost Solar Alone ($)'] = df['Electricity usage (kWh)'] * initial_electricity_price

# Calculate electricity cost for each hour using battery
df['Electricity Cost with Battery ($)'] = df['Electricity Bought with Battery (kWh)'] * initial_electricity_price

# Calculate the difference in electricity costs
df['Electricity Cost Savings ($)'] = df['Electricity Cost Solar Alone ($)'] - df['Electricity Cost with Battery ($)']

# Calculate total savings over 2020
total_savings = df['Electricity Cost Savings ($)'].sum()

print("Total savings over 2020: $", round(total_savings, 2))
# Out:
# Total savings over 2020: $ 414.67

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data (replace 'file_path' with your actual file path)
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum',
    'Electricity usage (kWh)_with_battery': 'sum',
    'Electricity usage (kWh)_without_battery': 'sum'
}).reset_index()

# Plot a bar chart
plt.figure(figsize=(10, 6))
plt.bar(monthly_data['Month'], monthly_data['Solar electricity generation (kWh)'], label='Solar Generation')
plt.bar(monthly_data['Month'], monthly_data['Electricity usage (kWh)'], label='Electricity Usage')
plt.bar(monthly_data['Month'], monthly_data['Electricity usage (kWh)_without_battery'], label='Electricity Purchased (without battery)')
plt.bar(monthly_data['Month'], monthly_data['Electricity usage (kWh)_with_battery'], label='Electricity Purchased (with battery)')
plt.xlabel('Month')
plt.ylabel('Energy (kWh)')
plt.title('Monthly Solar Generation, Electricity Usage, and Purchased Electricity')
plt.xticks(range(1, 13))
plt.legend()
plt.grid(True)
plt.show()

# Display the tabulated monthly data
print(monthly_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 10
#       8 # Calculate monthly values
#       9 df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
# ---> 10 monthly_data = df.groupby('Month').agg({
#      11     'Solar electricity generation (kWh)': 'sum',
#      12     'Electricity usage (kWh)': 'sum',
#      13     'Electricity usage (kWh)_with_battery': 'sum',
#      14     'Electricity usage (kWh)_without_battery': 'sum'
#      15 }).reset_index()
#      17 # Plot a bar chart
#      18 plt.figure(figsize=(10, 6))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/generic.py:895, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     892 func = maybe_mangle_lambdas(func)
#     894 op = GroupByApply(self, func, args, kwargs)
# --> 895 result = op.agg()
#     896 if not is_dict_like(func) and result is not None:
#     897     return result
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:496, in Apply.agg_dict_like(self)
#     493     selected_obj = obj._selected_obj
#     494     selection = obj._selection
# --> 496 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     498 if selected_obj.ndim == 1:
#     499     # key only used for output
#     500     colg = obj._gotitem(selection, ndim=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:619, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     617     if len(cols) > 0:
#     618         cols_sorted = list(safe_sort(list(cols)))
# --> 619         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     621 aggregator_types = (list, tuple, dict)
#     623 # if we have a dict of any non-scalars
#     624 # eg. {'A' : ['mean']}, normalize all to
#     625 # be list-likes
#     626 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Electricity usage (kWh)_with_battery', 'Electricity usage (kWh)_without_battery'] do not exist"

# %%
print(df.columns)
# Out:
# Index(['Hour', 'Date/hour start', 'Solar electricity generation (kWh)',
#        'Electricity usage (kWh)', 'Month'],
#       dtype='object')

# %%
# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum',
    'Electricity usage with battery (kWh)': 'sum',  # Correct column name with battery
    'Electricity usage without battery (kWh)': 'sum'  # Correct column name without battery
}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Calculate monthly values
#       2 df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
# ----> 3 monthly_data = df.groupby('Month').agg({
#       4     'Solar electricity generation (kWh)': 'sum',
#       5     'Electricity usage (kWh)': 'sum',
#       6     'Electricity usage with battery (kWh)': 'sum',  # Correct column name with battery
#       7     'Electricity usage without battery (kWh)': 'sum'  # Correct column name without battery
#       8 }).reset_index()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/generic.py:895, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     892 func = maybe_mangle_lambdas(func)
#     894 op = GroupByApply(self, func, args, kwargs)
# --> 895 result = op.agg()
#     896 if not is_dict_like(func) and result is not None:
#     897     return result
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:496, in Apply.agg_dict_like(self)
#     493     selected_obj = obj._selected_obj
#     494     selection = obj._selection
# --> 496 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     498 if selected_obj.ndim == 1:
#     499     # key only used for output
#     500     colg = obj._gotitem(selection, ndim=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:619, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     617     if len(cols) > 0:
#     618         cols_sorted = list(safe_sort(list(cols)))
# --> 619         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     621 aggregator_types = (list, tuple, dict)
#     623 # if we have a dict of any non-scalars
#     624 # eg. {'A' : ['mean']}, normalize all to
#     625 # be list-likes
#     626 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Electricity usage with battery (kWh)', 'Electricity usage without battery (kWh)'] do not exist"

# %%
# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum'
}).reset_index()

# %%
# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum'
}).reset_index()

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']
monthly_data['Electricity usage with battery (kWh)'] = df.groupby('Month')['Electricity usage with battery (kWh)'].sum()

# Calculate monthly electricity usage without battery
monthly_data['Electricity usage without battery (kWh)'] = monthly_data['Electricity usage (kWh)']

# Plot a bar chart
plt.figure(figsize=(10, 6))
plt.bar(monthly_data['Month'], monthly_data['Solar electricity generation (kWh)'], label='Solar generation')
plt.bar(monthly_data['Month'], monthly_data['Electricity usage (kWh)'], label='Electricity usage')
plt.bar(monthly_data['Month'], monthly_data['Electricity usage with battery (kWh)'], label='Electricity usage with battery')
plt.bar(monthly_data['Month'], monthly_data['Electricity usage without battery (kWh)'], label='Electricity usage without battery')
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Monthly Energy Usage')
plt.legend()
plt.xticks(range(1, 13))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Excess solar electricity (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 9
#       3 monthly_data = df.groupby('Month').agg({
#       4     'Solar electricity generation (kWh)': 'sum',
#       5     'Electricity usage (kWh)': 'sum'
#       6 }).reset_index()
#       8 # Calculate monthly electricity usage with battery
# ----> 9 df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']
#      10 monthly_data['Electricity usage with battery (kWh)'] = df.groupby('Month')['Electricity usage with battery (kWh)'].sum()
#      12 # Calculate monthly electricity usage without battery
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Excess solar electricity (kWh)'

# %%
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum',
    'Electricity usage (kWh)_without_battery': 'sum',
    'Electricity usage (kWh)_with_battery': 'sum'
}).reset_index()

# Create a table
table = monthly_data.rename(columns={
    'Solar electricity generation (kWh)': 'Monthly Solar Generation (kWh)',
    'Electricity usage (kWh)': 'Monthly Electricity Usage (kWh)',
    'Electricity usage (kWh)_without_battery': 'Monthly Electricity Purchased (No Battery) (kWh)',
    'Electricity usage (kWh)_with_battery': 'Monthly Electricity Purchased (With Battery) (kWh)'
})

# Print the table
print(table)

# Plot a bar chart
plt.figure(figsize=(10, 6))
plt.bar(table['Month'], table['Monthly Solar Generation (kWh)'], label='Solar Generation')
plt.bar(table['Month'], table['Monthly Electricity Usage (kWh)'], label='Electricity Usage', bottom=table['Monthly Solar Generation (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (No Battery) (kWh)'], label='Electricity Purchased (No Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (With Battery) (kWh)'], label='Electricity Purchased (With Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'] + table['Monthly Electricity Purchased (No Battery) (kWh)'])
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Monthly Electricity Metrics')
plt.xticks(table['Month'], ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 13
#      11 # Calculate monthly values
#      12 df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
# ---> 13 monthly_data = df.groupby('Month').agg({
#      14     'Solar electricity generation (kWh)': 'sum',
#      15     'Electricity usage (kWh)': 'sum',
#      16     'Electricity usage (kWh)_without_battery': 'sum',
#      17     'Electricity usage (kWh)_with_battery': 'sum'
#      18 }).reset_index()
#      20 # Create a table
#      21 table = monthly_data.rename(columns={
#      22     'Solar electricity generation (kWh)': 'Monthly Solar Generation (kWh)',
#      23     'Electricity usage (kWh)': 'Monthly Electricity Usage (kWh)',
#      24     'Electricity usage (kWh)_without_battery': 'Monthly Electricity Purchased (No Battery) (kWh)',
#      25     'Electricity usage (kWh)_with_battery': 'Monthly Electricity Purchased (With Battery) (kWh)'
#      26 })
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/generic.py:895, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     892 func = maybe_mangle_lambdas(func)
#     894 op = GroupByApply(self, func, args, kwargs)
# --> 895 result = op.agg()
#     896 if not is_dict_like(func) and result is not None:
#     897     return result
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:496, in Apply.agg_dict_like(self)
#     493     selected_obj = obj._selected_obj
#     494     selection = obj._selection
# --> 496 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     498 if selected_obj.ndim == 1:
#     499     # key only used for output
#     500     colg = obj._gotitem(selection, ndim=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:619, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     617     if len(cols) > 0:
#     618         cols_sorted = list(safe_sort(list(cols)))
# --> 619         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     621 aggregator_types = (list, tuple, dict)
#     623 # if we have a dict of any non-scalars
#     624 # eg. {'A' : ['mean']}, normalize all to
#     625 # be list-likes
#     626 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Electricity usage (kWh)_with_battery', 'Electricity usage (kWh)_without_battery'] do not exist"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df[' Solar electricity generation (kWh)'] - df[' Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    ' Solar electricity generation (kWh)': 'sum',
    ' Electricity usage (kWh)': 'sum',
    ' Electricity usage (kWh)_no battery': 'sum',
    ' Electricity usage (kWh)_with battery': 'sum'
}).reset_index()

# Create a table
table = monthly_data.rename(columns={
    ' Solar electricity generation (kWh)': 'Monthly Solar Generation (kWh)',
    ' Electricity usage (kWh)': 'Monthly Electricity Usage (kWh)',
    ' Electricity usage (kWh)_no battery': 'Monthly Electricity Purchased (No Battery) (kWh)',
    ' Electricity usage (kWh)_with battery': 'Monthly Electricity Purchased (With Battery) (kWh)'
})

# Print the table
print(table)

# Plot a bar chart
plt.figure(figsize=(10, 6))
plt.bar(table['Month'], table['Monthly Solar Generation (kWh)'], label='Solar Generation')
plt.bar(table['Month'], table['Monthly Electricity Usage (kWh)'], label='Electricity Usage', bottom=table['Monthly Solar Generation (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (No Battery) (kWh)'], label='Electricity Purchased (No Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (With Battery) (kWh)'], label='Electricity Purchased (With Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'] + table['Monthly Electricity Purchased (No Battery) (kWh)'])
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Monthly Electricity Metrics')
plt.xticks(table['Month'], ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Solar electricity generation (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 9
#       6 df = pd.read_excel(file_path, header=2)  # Specify the correct header row
#       8 # Calculate excess solar electricity
# ----> 9 df['Excess solar electricity (kWh)'] = df[' Solar electricity generation (kWh)'] - df[' Electricity usage (kWh)']
#      11 # Calculate monthly values
#      12 df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: ' Solar electricity generation (kWh)'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Remove leading and trailing spaces from column names
df.columns = df.columns.str.strip()

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum',
    'Electricity usage (kWh)_no battery': 'sum',
    'Electricity usage (kWh)_with battery': 'sum'
}).reset_index()

# Create a table
table = monthly_data.rename(columns={
    'Solar electricity generation (kWh)': 'Monthly Solar Generation (kWh)',
    'Electricity usage (kWh)': 'Monthly Electricity Usage (kWh)',
    'Electricity usage (kWh)_no battery': 'Monthly Electricity Purchased (No Battery) (kWh)',
    'Electricity usage (kWh)_with battery': 'Monthly Electricity Purchased (With Battery) (kWh)'
})

# Print the table
print(table)

# Plot a bar chart
plt.figure(figsize=(10, 6))
plt.bar(table['Month'], table['Monthly Solar Generation (kWh)'], label='Solar Generation')
plt.bar(table['Month'], table['Monthly Electricity Usage (kWh)'], label='Electricity Usage', bottom=table['Monthly Solar Generation (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (No Battery) (kWh)'], label='Electricity Purchased (No Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (With Battery) (kWh)'], label='Electricity Purchased (With Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'] + table['Monthly Electricity Purchased (No Battery) (kWh)'])
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Monthly Electricity Metrics')
plt.xticks(table['Month'], ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 16
#      14 # Calculate monthly values
#      15 df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
# ---> 16 monthly_data = df.groupby('Month').agg({
#      17     'Solar electricity generation (kWh)': 'sum',
#      18     'Electricity usage (kWh)': 'sum',
#      19     'Electricity usage (kWh)_no battery': 'sum',
#      20     'Electricity usage (kWh)_with battery': 'sum'
#      21 }).reset_index()
#      23 # Create a table
#      24 table = monthly_data.rename(columns={
#      25     'Solar electricity generation (kWh)': 'Monthly Solar Generation (kWh)',
#      26     'Electricity usage (kWh)': 'Monthly Electricity Usage (kWh)',
#      27     'Electricity usage (kWh)_no battery': 'Monthly Electricity Purchased (No Battery) (kWh)',
#      28     'Electricity usage (kWh)_with battery': 'Monthly Electricity Purchased (With Battery) (kWh)'
#      29 })
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/generic.py:895, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     892 func = maybe_mangle_lambdas(func)
#     894 op = GroupByApply(self, func, args, kwargs)
# --> 895 result = op.agg()
#     896 if not is_dict_like(func) and result is not None:
#     897     return result
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:496, in Apply.agg_dict_like(self)
#     493     selected_obj = obj._selected_obj
#     494     selection = obj._selection
# --> 496 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     498 if selected_obj.ndim == 1:
#     499     # key only used for output
#     500     colg = obj._gotitem(selection, ndim=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:619, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     617     if len(cols) > 0:
#     618         cols_sorted = list(safe_sort(list(cols)))
# --> 619         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     621 aggregator_types = (list, tuple, dict)
#     623 # if we have a dict of any non-scalars
#     624 # eg. {'A' : ['mean']}, normalize all to
#     625 # be list-likes
#     626 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Electricity usage (kWh)_no battery', 'Electricity usage (kWh)_with battery'] do not exist"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Remove leading and trailing spaces from column names
df.columns = df.columns.str.strip()

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month
monthly_data = df.groupby('Month').agg({
    'Solar electricity generation (kWh)': 'sum',
    'Electricity usage (kWh)': 'sum'
}).reset_index()

# Calculate monthly electricity usage with and without battery
df['Electricity usage (kWh)_with battery'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']
monthly_data['Electricity usage (kWh)_with battery'] = df.groupby('Month')['Electricity usage (kWh)_with battery'].sum()

# Create a table
table = monthly_data.rename(columns={
    'Solar electricity generation (kWh)': 'Monthly Solar Generation (kWh)',
    'Electricity usage (kWh)': 'Monthly Electricity Usage (kWh)',
    'Electricity usage (kWh)_with battery': 'Monthly Electricity Purchased (With Battery) (kWh)'
})

# Print the table
print(table)

# Plot a bar chart
plt.figure(figsize=(10, 6))
plt.bar(table['Month'], table['Monthly Solar Generation (kWh)'], label='Solar Generation')
plt.bar(table['Month'], table['Monthly Electricity Usage (kWh)'], label='Electricity Usage', bottom=table['Monthly Solar Generation (kWh)'])
plt.bar(table['Month'], table['Monthly Electricity Purchased (With Battery) (kWh)'], label='Electricity Purchased (With Battery)', bottom=table['Monthly Solar Generation (kWh)'] + table['Monthly Electricity Usage (kWh)'])
plt.xlabel('Month')
plt.ylabel('kWh')
plt.title('Monthly Electricity Metrics')
plt.xticks(table['Month'], ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.show()
# Out:
#     Month  Monthly Solar Generation (kWh)  Monthly Electricity Usage (kWh)  \
# 0       1                         266.259                     47705.180181
# 1       2                         449.634                      1557.578810
# 2       3                         602.451                      1797.859450
# 3       4                         915.132                      1726.356487
# 4       5                        1641.360                       943.803809
# 5       6                        1408.287                      1158.995538
# 6       7                        1371.465                      1196.957121
# 7       8                        1158.639                      1491.525351
# 8       9                         835.680                      1620.714165
# 9      10                         546.132                      1420.745585
# 10     11                         381.723                      1479.005869
# 11     12                         205.965                      1960.563395
#
#     Monthly Electricity Purchased (With Battery) (kWh)
# 0                                                 NaN
# 1                                        95144.101362
# 2                                         2665.523620
# 3                                         2993.267899
# 4                                         2537.580975
# 5                                          246.247618
# 6                                          909.704077
# 7                                         1022.449242
# 8                                         1824.411702
# 9                                         2405.748331
# 10                                        2295.359171
# 11                                        2576.288738

# %%
# Constants
discount_rate = 0.05  # Discount rate for NPV calculation
annual_price_increase_government = 0.04  # 4% annual increase in electricity prices by the government
annual_price_increase_naomi_base = 0.04  # 4% annual increase in electricity prices by Naomi initially
annual_price_increase_naomi_additional = 0.0025  # Additional 0.25% annual increase by Naomi each year

# Initial values
total_solar_generation = df['Solar electricity generation (kWh)'].sum()
total_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Project forward for 20 years and calculate savings and NPV for both scenarios
scenario_savings_npv = []
for year in range(2022, 2022 + 20):
    # Calculate electricity price for the year based on the scenarios
    electricity_price_government = 0.15 * (1 + annual_price_increase_government) ** (year - 2022)
    electricity_price_naomi = 0.15 * ((1 + annual_price_increase_naomi_base + annual_price_increase_naomi_additional * (year - 2022)) ** (year - 2022))
    
    # Calculate savings for Scenario 1 (Government)
    annual_electricity_usage_with_battery = total_solar_generation
    annual_savings_government = (total_electricity_usage_without_battery - annual_electricity_usage_with_battery) * electricity_price_government
    
    # Calculate savings for Scenario 2 (Naomi)
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + annual_price_increase_naomi_base + annual_price_increase_naomi_additional * (year - 2022))
    annual_savings_naomi = (total_electricity_usage_without_battery - total_electricity_usage_with_battery) * electricity_price_naomi
    
    # Calculate NPV for both scenarios
    npv_government = annual_savings_government / (1 + discount_rate) ** (year - 2022)
    npv_naomi = annual_savings_naomi / (1 + discount_rate) ** (year - 2022)
    
    scenario_savings_npv.append({
        'Year': year,
        'Savings (Government)': annual_savings_government,
        'NPV (Government)': npv_government,
        'Savings (Naomi)': annual_savings_naomi,
        'NPV (Naomi)': npv_naomi
    })

# Convert the results into a DataFrame
result_df = pd.DataFrame(scenario_savings_npv)

# Display the results
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Electricity usage with battery (kWh)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 23
#      20 annual_savings_government = (total_electricity_usage_without_battery - annual_electricity_usage_with_battery) * electricity_price_government
#      22 # Calculate savings for Scenario 2 (Naomi)
# ---> 23 total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
#      24 total_electricity_usage_with_battery *= (1 + annual_price_increase_naomi_base + annual_price_increase_naomi_additional * (year - 2022))
#      25 annual_savings_naomi = (total_electricity_usage_without_battery - total_electricity_usage_with_battery) * electricity_price_naomi
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Electricity usage with battery (kWh)'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate savings for Scenario 1 (Government)
electricity_price_government = 1.04  # 4% increase per year
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * electricity_price_government

# Calculate savings for Scenario 2 (Naomi)
electricity_price_naomi_base = 1.04  # 4% increase per year
electricity_price_naomi_additional = 0.0025  # 0.25% additional increase per year
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + electricity_price_naomi_base + electricity_price_naomi_additional * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * electricity_price_naomi_base

# Calculate NPV for Scenario 1 (Government)
discount_rate = 0.05  # 5% discount rate
npv_government = sum([(annual_savings_government / ((1 + discount_rate) ** year)) for year in range(1, 21)])

# Calculate NPV for Scenario 2 (Naomi)
npv_naomi = sum([(annual_savings_naomi / ((1 + discount_rate) ** year)) for year in range(1, 21)])

# Print results
print(f"Annual Savings (Government Scenario): ${annual_savings_government:.2f}")
print(f"Annual Savings (Naomi Scenario): ${annual_savings_naomi:.2f}")
print(f"NPV (Government Scenario): ${npv_government:.2f}")
print(f"NPV (Naomi Scenario): ${npv_naomi:.2f}")
# Out:
# Annual Savings (Government Scenario): $-56447.62
# Annual Savings (Naomi Scenario): $-3747251.32
# NPV (Government Scenario): $-703462.13
# NPV (Naomi Scenario): $-46699034.13

# %%
import pandas as pd
import numpy as np
from scipy.optimize import newton

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = newton(npv_function, x0=0.1, args=(annual_savings_government, 20, initial_battery_cost))

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = newton(npv_function, x0=0.1, args=(annual_savings_naomi, 20, initial_battery_cost))

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# /var/folders/2j/nvmx9r313gq5c9b1ndl9hp200000gn/T/ipykernel_6033/3082330420.py:26: RuntimeWarning: overflow encountered in double_scalars
#   return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = newton(npv_function, x0=0.1, args=(annual_savings_government, 20, initial_battery_cost))
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:348, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     344     if disp:
#     345         msg += (
#     346             " Failed to converge after %d iterations, value is %s."
#     347             % (itr + 1, p1))
# --> 348         raise RuntimeError(msg)
#     349     warnings.warn(msg, RuntimeWarning)
#     350 p = (p1 + p0) / 2.0
#
# RuntimeError: Tolerance of 6.695079432030766e+40 reached. Failed to converge after 18 iterations, value is 6.69507943203077e+40.

# %%
import pandas as pd
import numpy as np
from scipy.optimize import root_scalar

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = root_scalar(npv_function, bracket=[0, 1], args=(annual_savings_government, 20, initial_battery_cost)).root

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = root_scalar(npv_function, bracket=[0, 1], args=(annual_savings_naomi, 20, initial_battery_cost)).root

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = root_scalar(npv_function, bracket=[0, 1], args=(annual_savings_government, 20, initial_battery_cost)).root
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
import pandas as pd
import numpy as np
from scipy.optimize import root_scalar

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = root_scalar(npv_function, bracket=[-0.5, 0.5], args=(annual_savings_government, 20, initial_battery_cost)).root

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = root_scalar(npv_function, bracket=[-0.5, 0.5], args=(annual_savings_naomi, 20, initial_battery_cost)).root

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = root_scalar(npv_function, bracket=[-0.5, 0.5], args=(annual_savings_government, 20, initial_battery_cost)).root
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
import pandas as pd
import numpy as np
from scipy.optimize import root_scalar

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = root_scalar(npv_function, bracket=[-1.0, 1.0], args=(annual_savings_government, 20, initial_battery_cost)).root

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = root_scalar(npv_function, bracket=[-1.0, 1.0], args=(annual_savings_naomi, 20, initial_battery_cost)).root

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# /var/folders/2j/nvmx9r313gq5c9b1ndl9hp200000gn/T/ipykernel_6033/2095455550.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = root_scalar(npv_function, bracket=[-1.0, 1.0], args=(annual_savings_government, 20, initial_battery_cost)).root
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
import pandas as pd
import numpy as np
from scipy.optimize import root_scalar

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = root_scalar(npv_function, bracket=[-1.0, 0.5], args=(annual_savings_government, 20, initial_battery_cost)).root

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = root_scalar(npv_function, bracket=[-1.0, 0.5], args=(annual_savings_naomi, 20, initial_battery_cost)).root

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# /var/folders/2j/nvmx9r313gq5c9b1ndl9hp200000gn/T/ipykernel_6033/1381642533.py:26: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = root_scalar(npv_function, bracket=[-1.0, 0.5], args=(annual_savings_government, 20, initial_battery_cost)).root
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
import pandas as pd
import numpy as np
from scipy.optimize import root_scalar

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = root_scalar(npv_function, x0=0.1, bracket=[-0.5, 1.0], args=(annual_savings_government, 20, initial_battery_cost)).root

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = root_scalar(npv_function, x0=0.1, bracket=[-0.5, 1.0], args=(annual_savings_naomi, 20, initial_battery_cost)).root

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = root_scalar(npv_function, x0=0.1, bracket=[-0.5, 1.0], args=(annual_savings_government, 20, initial_battery_cost)).root
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
import pandas as pd
import numpy as np
from scipy.optimize import root_scalar

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = root_scalar(npv_function, bracket=[-2.0, 2.0], x0=0.1, args=(annual_savings_government, 20, initial_battery_cost)).root

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = root_scalar(npv_function, bracket=[-2.0, 2.0], x0=0.1, args=(annual_savings_naomi, 20, initial_battery_cost)).root

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 30
#      28 # Calculate IRR for Scenario 1 (Government)
#      29 annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
# ---> 30 irr_government = root_scalar(npv_function, bracket=[-2.0, 2.0], x0=0.1, args=(annual_savings_government, 20, initial_battery_cost)).root
#      32 # Calculate IRR for Scenario 2 (Naomi)
#      33 annual_savings_naomi = 0
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_root_scalar.py:275, in root_scalar(f, args, method, bracket, fprime, fprime2, x0, x1, xtol, rtol, maxiter, options)
#     272         raise ValueError('Bracket needed for %s' % method)
#     274     a, b = bracket[:2]
# --> 275     r, sol = methodc(f, a, b, args=args, **kwargs)
#     276 elif meth in ['secant']:
#     277     if x0 is None:
#
# File ~/anaconda3/lib/python3.10/site-packages/scipy/optimize/_zeros_py.py:784, in brentq(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     782 if rtol < _rtol:
#     783     raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 784 r = _zeros._brentq(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     785 return results_c(full_output, r)
#
# ValueError: f(a) and f(b) must have different signs

# %%
import pandas as pd
import numpy as np
from scipy.optimize import fsolve

# Load the data from the Excel file
file_path = '/Users/admin/Downloads/Junior Data Analyst _ Data.xlsx'
df = pd.read_excel(file_path, header=2)  # Specify the correct header row

# Calculate excess solar electricity
df['Excess solar electricity (kWh)'] = df['Solar electricity generation (kWh)'] - df['Electricity usage (kWh)']

# Calculate monthly values
df['Month'] = pd.to_datetime(df['Date/hour start']).dt.month

# Calculate monthly electricity usage with battery
df['Electricity usage with battery (kWh)'] = df['Electricity usage (kWh)'] - df['Excess solar electricity (kWh)']

# Calculate annual electricity usage without battery
annual_electricity_usage_without_battery = df['Electricity usage (kWh)'].sum()

# Calculate initial cost of battery (you need to replace this with the actual cost)
initial_battery_cost = 10000.0  # Example initial cost of the battery

# Define the NPV function to find the IRR
def npv_function(rate, annual_savings, years, initial_cost):
    return np.sum([annual_savings / ((1 + rate) ** year) for year in range(1, years + 1)]) - initial_cost

# Calculate IRR for Scenario 1 (Government)
annual_savings_government = (annual_electricity_usage_without_battery - df['Electricity usage with battery (kWh)'].sum()) * 1.04
irr_government = fsolve(npv_function, x0=0.1, args=(annual_savings_government, 20, initial_battery_cost))[0]

# Calculate IRR for Scenario 2 (Naomi)
annual_savings_naomi = 0
for year in range(2022, 2022 + 20):
    total_electricity_usage_with_battery = df['Electricity usage with battery (kWh)'].sum()
    total_electricity_usage_with_battery *= (1 + 1.04 + 0.0025 * (year - 2022))
    annual_savings_naomi += (annual_electricity_usage_without_battery - total_electricity_usage_with_battery) * 1.04

irr_naomi = fsolve(npv_function, x0=0.1, args=(annual_savings_naomi, 20, initial_battery_cost))[0]

# Print results
print(f"IRR (Government Scenario): {irr_government * 100:.2f}%")
print(f"IRR (Naomi Scenario): {irr_naomi * 100:.2f}%")
# Out:
# IRR (Government Scenario): 610568739.19%
# IRR (Naomi Scenario): 49958229367.02%
# /Users/admin/anaconda3/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:178: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
